# %% [markdown]
# <a href="https://colab.research.google.com/github/FARIDAblaq/cryptowallets/blob/main/cryptowallet_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing Packages

# %%
install.packages("tidyverse")
install.packages("ggthemes")
install.packages("xlsx")
install.packages("readxl")
# install.packages("drive")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rJava’, ‘xlsxjars’
#
#
# Warning message in install.packages("xlsx"):
# “installation of package ‘rJava’ had non-zero exit status”
# Warning message in install.packages("xlsx"):
# “installation of package ‘xlsxjars’ had non-zero exit status”
# Warning message in install.packages("xlsx"):
# “installation of package ‘xlsx’ had non-zero exit status”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Calling all Libraries

# %%
library(readxl)
library(tidyverse)
library(ggthemes)

# %%
data <- read_excel("Crypto_survey.xlsx")

# %%
library(dplyr)
data_cleaned <- data %>% select(Q1:Q40_6_TEXT)
head(data_cleaned)
# Out:
#   Q1                             Q2
# 1 Are you at least 18 years old? How long have you been using crypto?
# 2 Yes                            More than 5 years
# 3 Yes                            1 to 2 years
# 4 Yes                            2 to 5 years
# 5 Yes                            Less than 6 months
# 6 Yes                            6 months to 1 year
#   Q3_1
# 1 What motivated you to start trading crypto? Choose all that apply. - Selected Choice - Research (i.e to research how it works, scholarly purposes, etc)
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
#   Q3_2
# 1 What motivated you to start trading crypto? Choose all that apply. - Selected Choice - Financial Planning (i.e. investment)
# 2 NA
# 3 Financial Planning (i.e. investment)
# 4 Financial Planning (i.e. investment)
# 5 NA
# 6 Financial Planning (i.e. investment)
#   Q3_3
# 1 What motivated you to start trading crypto? Choose all that apply. - Selected Choice - Work (i.e for a business transaction)
# 2 NA
# 3 NA
# 4 NA
# ...

# %%
data_finale <- data_cleaned %>% slice(2:nrow(data))
head(data_finale)
# Out:
#   Q1  Q2
# 1 Yes More than 5 years
# 2 Yes 1 to 2 years
# 3 Yes 2 to 5 years
# 4 Yes Less than 6 months
# 5 Yes 6 months to 1 year
# 6 Yes 1 to 2 years
#   Q3_1
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 Research (i.e to research how it works, scholarly purposes, etc)
#   Q3_2                                 Q3_3 Q3_4 Q3_5
# 1 NA                                   NA   NA   Entertainment
# 2 Financial Planning (i.e. investment) NA   NA   NA
# 3 Financial Planning (i.e. investment) NA   NA   NA
# 4 NA                                   NA   NA   Entertainment
# 5 Financial Planning (i.e. investment) NA   NA   NA
# 6 NA                                   NA   NA   NA
#   Q3_6                   Q3_6_TEXT
# 1 NA                     NA
# 2 NA                     NA
# 3 NA                     NA
# 4 Other (please specify) Mostly I store
# 5 NA                     NA
# 6 NA                     NA
#   Q4_1
# 1 NA
# 2 NA
# ...

# %% [markdown]
# Descriptive analysis of All data
# Distribution of "Q8: As it relates to cryptocurrencies/web3, please select the option that best represents this image:"

# %%
seedphrase_dist <-table(data_finale$Q8)
seedphrase_dist
# Out:
#      Address      CAPTCHA I don't know     Password  Seed Phrase
#           27           79          144          114          279

# %% [markdown]
# Q2: How long have you been using crypto

# %%
yrs_of_exp <- as.data.frame(table(data_finale$Q2))
print(yrs_of_exp)
# Out:
#                 Var1 Freq
# 1       1 to 2 years  177
# 2       2 to 5 years  143
# 3 6 months to 1 year  135
# 4 Less than 6 months  132
# 5  More than 5 years   56

# %%
ggplot(data_finale, aes(x= fct_infreq(Q2))) +geom_bar() + labs(title = "Q2: How long have you been using crypto?", x = "Years of Experience", y = "Frequency")
# Out:
# plot without title

# %% [markdown]
# #Q3:What motivated you to start trading crypto? Choose all that apply

# %%
motivation <- data.frame(data_finale$Q3_1,data_finale$Q3_2,data_finale$Q3_3,data_finale$Q3_4,data_finale$Q3_5)
q3 <- data.frame(
  option = c("Research", "Financial Planning", "Work", "Monetary transactions", "Entertainment"),
  nums = c(251,327,90,207,181)
)
q3
# Out:
#   option                nums
# 1 Research              251
# 2 Financial Planning    327
# 3 Work                   90
# 4 Monetary transactions 207
# 5 Entertainment         181

# %%
mot_overall <- data_finale[, paste0("Q3_", 1:5)]

#
mot_overall[mot_overall != ""] <- "Motivation"
mot_overall[mot_overall == ""] <- NA

# Convert the data to long format
responses_long <- gather(mot_overall, key = "Question", value = "Chosen")

option_names <- c(
  "Q3_1" = "Research",
  "Q3_2" = "Financial Planning",
  "Q3_3" = "Work",
  "Q3_4" = "Monetary Transactions",
  "Q3_5" = "Entertainment"
)
responses_long$Question <- option_names[responses_long$Question]
# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "What motivated you to start using crypto?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# #Q4: What kind of wallet do you mostly use?

# %%
kind_of_wallet_tablet <- data.frame(table(data_finale$Q4_1),table(data_finale$Q4_2),table(data_finale$Q4_3),table(data_finale$Q4_4),table(data_finale$Q4_5),table(data_finale$Q4_6),table(data_finale$Q4_7))
q4_table<-data.frame(
  option = c("Hosted Web wallet", "Non-Hosted Web wallet", "Desktop Wallet", "Mobile wallet", "Hardware wallet","Paper wallet","Other"),
  nums = c(339,95,187,234,63,9,9)
)
q4_table
# Out:
#   option                nums
# 1 Hosted Web wallet     339
# 2 Non-Hosted Web wallet  95
# 3 Desktop Wallet        187
# 4 Mobile wallet         234
# 5 Hardware wallet        63
# 6 Paper wallet            9
# 7 Other                   9

# %% [markdown]
# #Q5:What is your most used crypto trading platform? - Selected Choice

# %%
most_used_crypto_platform <- as.data.frame(table(data_finale$Q5))
print(most_used_crypto_platform)

#print barplot
ggplot(data_finale, aes(x= fct_infreq(Q5))) +geom_bar() + labs(title = "Q5:What is your most used crypto trading platform? - Selected Choice", x = "Platform", y = "Frequency")
# Out:
#                     Var1 Freq
# 1                Binance   87
# 2        Coinbase wallet  349
# 3           Coinbase web  121
# 4               Metamask   45
# 5 Other (please specify)   41
# plot without title

# %% [markdown]
# #Q6: How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)

# %%
num_of_active_trading_wallet <- data_finale$Q6
print(as.data.frame(table(num_of_active_trading_wallet)))
# print(num_of_active_trading_wallet)

#print barplot
ggplot(data_finale, aes(x= fct_infreq(Q6))) +geom_bar() + labs(title = " How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)", x = "Number of Active trading wallet", y = "Frequency")
# Out:
#   num_of_active_trading_wallet Freq
# 1                            0   26
# 2                          1-5  557
# 3                         5-10   45
# 4                 More than 10   15
# plot without title

# %% [markdown]
# #Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)

# %%
num_of_active_transactions_in_pastmth <- as.data.frame(table(data_finale$Q7))
print(num_of_active_transactions_in_pastmth)

#print barplot
ggplot(data_finale, aes(x= fct_infreq(Q7))) +geom_bar() + labs(title = " Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)", x = "Number of transactions", y = "Frequency")
# Out:
#           Var1 Freq
# 1            0   87
# 2          1-5  377
# 3         5-10  121
# 4 More than 10   58
# plot without title

# %% [markdown]
# #Q8: As it relates to cryptocurrencies/web3, please select the option that best represents this image: 43.39%

# %%
dist <- data_finale$Q8
freq_df <- as.data.frame(table(dist))
print(freq_df)
ggplot(data_finale, aes(x= fct_infreq(Q8))) +geom_bar() + labs(title = "Q8: As it relates to cryptocurrencies/web3, please select the option that best represents this image:", x = "Options", y = "Frequency")
# Out:
#           dist Freq
# 1      Address   27
# 2      CAPTCHA   79
# 3 I don't know  144
# 4     Password  114
# 5  Seed Phrase  279
# plot without title

# %% [markdown]
# #Filter out data based on seed phrase and others
# Those that answered seedphrase correctly

# %%
 answered_seedphrase_correctly <-data_finale |>
filter(Q8 == "Seed Phrase")
head(answered_seedphrase_correctly)
# Out:
#   Q1  Q2
# 1 Yes 6 months to 1 year
# 2 Yes 1 to 2 years
# 3 Yes 2 to 5 years
# 4 Yes 1 to 2 years
# 5 Yes Less than 6 months
# 6 Yes More than 5 years
#   Q3_1
# 1 NA
# 2 NA
# 3 Research (i.e to research how it works, scholarly purposes, etc)
# 4 NA
# 5 Research (i.e to research how it works, scholarly purposes, etc)
# 6 NA
#   Q3_2                                 Q3_3
# 1 Financial Planning (i.e. investment) NA
# 2 Financial Planning (i.e. investment) NA
# 3 NA                                   NA
# 4 NA                                   NA
# 5 Financial Planning (i.e. investment) NA
# 6 Financial Planning (i.e. investment) NA
#   Q3_4                                                          Q3_5 Q3_6
# 1 NA                                                            NA   NA
# 2 Monetary transactions (i.e, transfer funds, pay for products) NA   NA
# 3 NA                                                            NA   NA
# ...

# %% [markdown]
# #From here is an exploratory analysis of those that answered seedphrase correctly
# Q2 -How long have you been using crypto? - Only seed phrases

# %%
# freq table
yrs <- answered_seedphrase_correctly$Q2
freq_df <- as.data.frame(table(yrs))
print(freq_df)

ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q2))) +geom_bar() + labs(title = "Q2: How long have you been using crypto?", x = "Years of Experience", y = "Frequency")
# Out:
#                  yrs Freq
# 1       1 to 2 years   80
# 2       2 to 5 years   74
# 3 6 months to 1 year   48
# 4 Less than 6 months   46
# 5  More than 5 years   31
# plot without title

# %% [markdown]
# More experienced traders than novices. confirms with overall data

# %% [markdown]
# #Q3 - What motivated you to start trading crypto?

# %%
# motivation_cor <- data.frame(answered_seedphrase_correctly$Q3_1,answered_seedphrase_correctly$Q3_2,answered_seedphrase_correctly$Q3_3,answered_seedphrase_correctly$Q3_4,answered_seedphrase_correctly$Q3_5)
# print(motivation_cor)

# %%
#freq table for motivation of crypto use
research <- table(answered_seedphrase_correctly$Q3_1)
print(research)
fin_pl <- table(answered_seedphrase_correctly$Q3_2)
print(fin_pl)
work <- table(answered_seedphrase_correctly$Q3_3)
print(work)
mon_tr <- table(answered_seedphrase_correctly$Q3_4)
print(mon_tr)
ent <- table(answered_seedphrase_correctly$Q3_5)
print(ent)
# Out:
# Research (i.e to research how it works, scholarly purposes, etc)
#                                                              119
#
# Financial Planning (i.e. investment)
#                                  160
#
# Work (i.e for a business transaction)
#                                    36
#
# Monetary transactions (i.e, transfer funds, pay for products)
#                                                           111
#
# Entertainment
#            79

# %%
#plot a bar plot
# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q3_", 1:5)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "option"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q3_1" = "Research",
  "Q3_2" = "Financial Planning",
  "Q3_3" = "Work",
  "Q3_4" = "Monetary transactions",
  "Q3_5" = "Entertainment"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "What motivated you to start trading crypto?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Conforming to motivations from overall data on motivations, financial planning and research remains the biggest motivation and work is the lowest.

# %% [markdown]
# #Q4: What kind of wallet do you mostly use?

# %%
kind_of_wallet_tablet_cor <- data.frame(table(answered_seedphrase_correctly$Q4_1),table(answered_seedphrase_correctly$Q4_2),table(answered_seedphrase_correctly$Q4_3),table(answered_seedphrase_correctly$Q4_4),table(answered_seedphrase_correctly$Q4_5),table(answered_seedphrase_correctly$Q4_6),table(answered_seedphrase_correctly$Q4_7))
kind_of_wallet_tablet_cor <- t(kind_of_wallet_tablet_cor)
print(kind_of_wallet_tablet_cor)
# Out:
#        [,1]
# Var1   "Hosted Web Wallet (e.g., wallets provided by cryptocurrency exchanges like Coinbase, Gemini, and Binance)"
# Freq   "166"
# Var1.1 "Non-hosted Web Wallet (e.g., MetaMask, Electrum, MyEtherWallet)"
# Freq.1 "49"
# Var1.2 "Desktop Wallet (e.g., Bitcoin Core, Exodus, Armory, Wasabi Wallet)"
# Freq.2 "84"
# Var1.3 "Mobile Wallet (e.g., BRD, Mycelium, Trust Wallet)"
# Freq.3 "100"
# Var1.4 "Hardware Wallet (e.g., Ledger Nano S, Trezor, BitBox)"
# Freq.4 "34"
# Var1.5 "Paper Wallet (Offline paper storage)"
# Freq.5 "19"
# Var1.6 "Other (please specify)"
# Freq.6 "4"

# %% [markdown]
# #Q5:What is your most used crypto trading platform? - Selected Choice

# %%
most_used_crypto_platform_cor <- as.data.frame(table(answered_seedphrase_correctly$Q5))
print(most_used_crypto_platform_cor)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q5))) +geom_bar() + labs(title = "Q5:What is your most used crypto trading platform? - Selected Choice", x = "Platform", y = "Frequency")
# Out:
#                     Var1 Freq
# 1                Binance   30
# 2        Coinbase wallet  154
# 3           Coinbase web   56
# 4               Metamask   20
# 5 Other (please specify)   19
# plot without title

# %% [markdown]
# #Q6: How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)

# %%
num_of_active_trading_wallet_cor <- answered_seedphrase_correctly$Q6
print(as.data.frame(table(num_of_active_trading_wallet)))
# print(num_of_active_trading_wallet)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q6))) +geom_bar() + labs(title = " How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)", x = "Number of Active trading wallet", y = "Frequency")
# Out:
#   num_of_active_trading_wallet Freq
# 1                            0   26
# 2                          1-5  557
# 3                         5-10   45
# 4                 More than 10   15
# plot without title

# %% [markdown]
# #Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)

# %%
num_of_active_transactions_in_pastmth <- as.data.frame(table(answered_seedphrase_correctly$Q7))
print(num_of_active_transactions_in_pastmth)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q7))) +geom_bar() + labs(title = " Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)", x = "Number of transactions", y = "Frequency")
# Out:
#           Var1 Freq
# 1            0   27
# 2          1-5  162
# 3         5-10   62
# 4 More than 10   28
# plot without title

# %% [markdown]
# Q9: Please select one Non-Hosted wallet (e.g., MetaMask, Electrum, Trust Wallet) that you use most frequently or value highly. Non-Hosted wallets are where you control your private keys directly. Write down the name of this wallet below, such as 'MetaMask'. Your answers to all the following questions will focus on this specific wallet.

# %%
dist_of_non_hosted_wallet_cor <- answered_seedphrase_correctly$Q9
print(as.data.frame(table(dist_of_non_hosted_wallet_cor)))


#print barplot
ggplot(answered_seedphrase_correctly, aes(x = fct_infreq(Q9))) +
  geom_bar() +
  labs(title = " Non-Hosted wallet (e.g., MetaMask, Electrum, Trust Wallet)
       that you use most frequently or value highly.",
       x = "Non-Hosted wallet",
       y = "Frequency") +
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1)) # Rotating x-axis labels vertically
# Out:
#    dist_of_non_hosted_wallet_cor Freq
# 1                        Airzuit    1
# 2                   Apple wallet    2
# 3                   Apple Wallet    1
# 4                        Barcode    1
# 5                       Betamask    1
# 6                        Binance    1
# 7                       BitBox02    1
# 8                        Bitcoin    2
# 9              Blockstream Green    1
# 10                      cash app    1
# 11                      Cash app    2
# 12                      Cash App    1
# 13                         chase    1
# 14                     Coin Base    2
# 15                   Coin pocket    1
# 16                      CoinBank    1
# 17                      coinbase    2
# 18                      Coinbase   22
# 19                      CoinBase    2
# 20               Coinbase Wallet    2
# 21                        crypto    1
# 22                        Crypto    4
# 23                 Crypto wallet    1
# 24                Dogewallet.org    1
# ...

# %% [markdown]
# Q10: If you change your device and need to transfer everything into that new device, what information or items are generally required to import your cryptocurrency wallet to your new device? Assume you still have access to your wallet application but need to restore your account. (Choose the minimum required)

# %%
items_to_import <- data.frame(table(answered_seedphrase_correctly$Q10_1),table(answered_seedphrase_correctly$Q10_2),table(answered_seedphrase_correctly$Q10_3),table(answered_seedphrase_correctly$Q10_4),table(answered_seedphrase_correctly$Q10_5),table(answered_seedphrase_correctly$Q10_6),table(answered_seedphrase_correctly$Q10_7),table(answered_seedphrase_correctly$Q10_8),table(answered_seedphrase_correctly$Q10_9),table(answered_seedphrase_correctly$Q10_10))
items_to_import <- t(items_to_import)
print(items_to_import)
# Out:
#        [,1]
# Var1   "Username and Password"
# Freq   "147"
# Var1.1 "Private Key"
# Freq.1 "110"
# Var1.2 "Recovery Seed Phrase"
# Freq.2 "133"
# Var1.3 "Wallet Password"
# Freq.3 "98"
# Var1.4 "Two-Factor Authentication Codes"
# Freq.4 "109"
# Var1.5 "Email Address associated with Wallet"
# Freq.5 "93"
# Var1.6 "Backup Files from Wallet Application"
# Freq.6 "43"
# Var1.7 "None of the Above"
# Freq.7 "1"
# Var1.8 "I don't know"
# Freq.8 "12"
# Var1.9 "Other (please specify)"
# Freq.9 "2"

# %%
# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q10_", 1:10)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "X"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
        "Q10_1" = "Username_and_Password",
         "Q10_2" = "Private_Key",
         "Q10_3" = "Recovery_Seed_Phrase",
         "Q10_4" = " Wallet_Password",
         "Q10_5" = "Two-Factor_Auth",
         "Q10_6" = "Email_Address",
         "Q10_7" = "Backup_Files",
         "Q10_8" = "None_of_the_Above",
         "Q10_9" = "I_don't_know",
         "Q10_10" = "Other_"
)

responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "If you change your device and need to transfer everything into
       that new device, what information or items are generally required to
       import your cryptocurrency wallet to your new device?",
       x = "Question",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Q11: Imagine a scenario where both your computer and phone were stolen, making your digital wallet inaccessible. Which of the following would you need for successful account recovery? Choose all that apply.

# %%
sus_acc_rec <- data.frame(table(answered_seedphrase_correctly$Q11_1),table(answered_seedphrase_correctly$Q11_2),table(answered_seedphrase_correctly$Q11_3),table(answered_seedphrase_correctly$Q11_4),table(answered_seedphrase_correctly$Q11_5),table(answered_seedphrase_correctly$Q11_6),table(answered_seedphrase_correctly$Q11_7),table(answered_seedphrase_correctly$Q11_8))
sus_acc_rec <- t(sus_acc_rec)
print(sus_acc_rec)
# Out:
#        [,1]
# Var1   "Recovery Seed Phrase"
# Freq   "158"
# Var1.1 "Private Key"
# Freq.1 "122"
# Var1.2 "Hardware device, such as a USB drive, or other external storage"
# Freq.2 "55"
# Var1.3 "Access to Registered Email or Phone Number for Verification"
# Freq.3 "108"
# Var1.4 "Physical Security Token or Two-Factor Authentication Device"
# Freq.4 "76"
# Var1.5 "A New Device with the Wallet Application Installed"
# Freq.5 "60"
# Var1.6 "None of the Above"
# Freq.6 "4"
# Var1.7 "I don't know"
# Freq.7 "13"

# %%
# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q11_", 1:8)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "Options"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
         "Q11_1" = "Recovery Seed Phrase",
         "Q11_2" = "Private_Key",
         "Q11_3" = "Hardware device",
         "Q11_4" = " Access to Registered Email",
         "Q11_5" = "Physical Security Token",
         "Q11_6" = "A New Device with the Wallet Application Installed",
         "Q11_7" = "None_of_the_Above",
         "Q11_8" = "I_don't_know"
)

responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "Which of the following would you need for successful account recovery?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# #Q12: Can you choose your own wallet account seed phrases?

# %%
choose_seed_phrase <- as.data.frame(table(answered_seedphrase_correctly$Q12))
print(choose_seed_phrase)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q12))) +geom_bar() + labs(title = "Can you choose your own wallet account seed phrases? - Selected Choice", x = "Option", y = "Frequency")
# Out:
#                                                                      Var1 Freq
# 1                                              No, they cannot be chosen.  112
# 2 Yes, I can choose it like I choose the account password for other apps.  167
# plot without title

# %% [markdown]
# So many people seem to think you can choose your own seed phrase.

# %% [markdown]
# #Q13: Have you ever fallen for any scams and/or did something wrong with your seed phrases?

# %%
fallen_for_scams <- as.data.frame(table(answered_seedphrase_correctly$Q13))
print(fallen_for_scams)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q13))) +geom_bar() + labs(title = "#Q13: Have you ever fallen for any scams and/or did something wrong with your seed phrases?", x = "Option", y = "Frequency")
# Out:
#           Var1 Freq
# 1       Never.  208
# 2 Yes, I have.   71
# plot without title

# %% [markdown]
# 25.44% have fallen for scams. Which is a quarter of those that know what a seed phrase is.

# %% [markdown]
# #Q15 On a scale from 1-5, for each of the following behaviors, choose how much you agree with the following statement: This behavior will keep my crypto wallet safe.

# %% [markdown]
# Using a password manager to avoid reusing passwords

# %%
reusing_passwords <- as.data.frame(table(answered_seedphrase_correctly$Q15_1))
print(reusing_passwords)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_1))) +geom_bar() + labs(title = "Using a password manager to avoid reusing passwords", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   21
# 2          2 - Disagree   22
# 3           3 - Neutral   68
# 4             4 - Agree  110
# 5    5 - Strongly agree   58
# plot without title

# %% [markdown]
# This is interesting.

# %% [markdown]
# # Sharing seed phrase on public forum

# %%
sharing_seedphrases <- as.data.frame(table(answered_seedphrase_correctly$Q15_2))
print(reusing_passwords)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_2))) +geom_bar() + labs(title = "Sharing seed phrase on public forum", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   21
# 2          2 - Disagree   22
# 3           3 - Neutral   68
# 4             4 - Agree  110
# 5    5 - Strongly agree   58
# plot without title

# %% [markdown]
# Same people also think this is safe.

# %% [markdown]
# # Back up crypto wallet periodically

# %%
backup_wallet <- as.data.frame(table(answered_seedphrase_correctly$Q15_3))
print(backup_wallet)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_3))) +geom_bar() + labs(title = "Back up crypto wallet", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree    7
# 2          2 - Disagree   13
# 3           3 - Neutral   63
# 4             4 - Agree  124
# 5    5 - Strongly agree   72
# plot without title

# %% [markdown]
# # Using public Wi-Fi to access crypto wallets or perform transactions

# %%
public_wifi <- as.data.frame(table(answered_seedphrase_correctly$Q15_4))
print(public_wifi)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_4))) +geom_bar() + labs(title = "Using public Wi-Fi to access crypto wallets or perform transactions", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree  107
# 2          2 - Disagree   51
# 3           3 - Neutral   51
# 4             4 - Agree   53
# 5    5 - Strongly agree   17
# plot without title

# %% [markdown]
# This is fair, but interesting. However, 43.37% are neutral or think it's safe to use public wifi to access their crypto assets.

# %% [markdown]
# #Using cloud storage services to store a backup of your seed phrase

# %%
cloud_storage_backup <- as.data.frame(table(answered_seedphrase_correctly$Q15_5))
print(cloud_storage_backup)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_5))) +geom_bar() + labs(title = "Using public Wi-Fi to access crypto wallets or perform transactions", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   41
# 2          2 - Disagree   44
# 3           3 - Neutral   70
# 4             4 - Agree   83
# 5    5 - Strongly agree   41
# plot without title

# %% [markdown]
# 44.44% think it's safe, 30.47% think it's unsafe. The rest are neutral.

# %% [markdown]
# #Storing a large percentage of your crypto assets in an online wallet

# %%
storage_in_an_online_wallet <- as.data.frame(table(answered_seedphrase_correctly$Q15_6))
print(storage_in_an_online_wallet)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_6))) +geom_bar() + labs(title = "Storing a large percentage of your crypto assets in an online wallet", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q15_6)) +geom_bar() + labs(title = "Storing a large percentage of your crypto assets in an online wallet", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   34
# 2          2 - Disagree   46
# 3           3 - Neutral   94
# 4             4 - Agree   71
# 5    5 - Strongly agree   34
# plot without title
# plot without title

# %% [markdown]
# Is it okay that most people are neutral? It could mean that they don't know.

# %% [markdown]
# #Log into crypto accounts and make transactions on multiple devices

# %%
trans_on_mult_dev <- as.data.frame(table(answered_seedphrase_correctly$Q15_7))
print(trans_on_mult_dev)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q15_7))) +geom_bar() + labs(title = "Log into crypto accounts and make transactions on multiple devices", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q15_7)) +geom_bar() + labs(title = "Log into crypto accounts and make transactions on multiple devices", x = "Option", y = "Frequency")
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   43
# 2          2 - Disagree   65
# 3           3 - Neutral   75
# 4             4 - Agree   71
# 5    5 - Strongly agree   25
# plot without title
# plot without title

# %% [markdown]
# Even though most agree that it is safe. So many people are neutral here too. How do we intepret their neutrality for each question? will it be the same?

# %% [markdown]
# #Q16: How do you currently back up your cryptocurrency wallet's seed phrases? (Check all that apply)

# %%
sus_seed_backup <- data.frame(table(answered_seedphrase_correctly$Q16_1),table(answered_seedphrase_correctly$Q16_2),table(answered_seedphrase_correctly$Q16_3),table(answered_seedphrase_correctly$Q16_4),table(answered_seedphrase_correctly$Q16_5),table(answered_seedphrase_correctly$Q16_6),table(answered_seedphrase_correctly$Q16_7),table(answered_seedphrase_correctly$Q16_8))
sus_seed_backup <- t(sus_seed_backup)
print(sus_seed_backup)
# Out:
#        [,1]
# Var1   "I don't backup my seed phrases"
# Freq   "20"
# Var1.1 "Paper Backup: Writing the seed phrase on paper and storing it securely."
# Freq.1 "107"
# Var1.2 "External Drive: Saving on a USB drive or external hard disk."
# Freq.2 "87"
# Var1.3 "Internal Drive: Storing in a file on your computer's hard drive."
# Freq.3 "63"
# Var1.4 "Cloud Service: Using services like Google Drive or Dropbox."
# Freq.4 "88"
# Var1.5 "Email: Keeping a copy in your email account."
# Freq.5 "70"
# Var1.6 "Memorizing in the brain."
# Freq.6 "40"
# Var1.7 "Other (Please specify)"
# Freq.7 "4"

# %% [markdown]
# It's interesting that paper backup is the most used strategy.

# %%
# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q16_", 1:8)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "X"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q16_1" = "None",
  "Q16_2" = "Paper Backup",
  "Q16_3" = "External Drive",
  "Q16_4" = "Internal Drive",
  "Q16_5" = "Cloud Service",
  "Q16_6" = "Email",
  "Q16_7" = "Memorizing",
  "Q16_8" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "How do you currently back up your cryptocurrency wallet's seed phrases?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# #Q17:On a scale of 1-5, choose how much you agree with the following statement: I feel that this method makes it easy for me to access my seed phrase backup.
# #Paper backup

# %%
paper_backup <- as.data.frame(table(answered_seedphrase_correctly$Q17_1))
print(paper_backup)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_1))) +geom_bar() + labs(title = "I feel that paper back up makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_1)) +geom_bar() + labs(title = "I feel that paper backup makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   13
# 2                2 - Disagree   23
# 3                 3 - Neutral   49
# 4                   4 - Agree   86
# 5          5 - Strongly agree   75
# 6 I have not used this method   13
# plot without title
# plot without title

# %% [markdown]
# #External Drive

# %%
external_drive <- as.data.frame(table(answered_seedphrase_correctly$Q17_2))
print(external_drive)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_2))) +geom_bar() + labs(title = "I feel that external_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_1)) +geom_bar() + labs(title = "I feel that external_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   12
# 2                2 - Disagree   22
# 3                 3 - Neutral   60
# 4                   4 - Agree   88
# 5          5 - Strongly agree   55
# 6 I have not used this method   22
# plot without title
# plot without title

# %% [markdown]
# # Internal Drive

# %%
internal_drive <- as.data.frame(table(answered_seedphrase_correctly$Q17_3))
print(internal_drive)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_3))) +geom_bar() + labs(title = "I feel that internal_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_3)) +geom_bar() + labs(title = "I feel that internal_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   11
# 2                2 - Disagree   28
# 3                 3 - Neutral   57
# 4                   4 - Agree   85
# 5          5 - Strongly agree   58
# 6 I have not used this method   20
# plot without title
# plot without title

# %% [markdown]
# #Cloud Service

# %%
cloud_service <- as.data.frame(table(answered_seedphrase_correctly$Q17_4))
print(cloud_service)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_4))) +geom_bar() + labs(title = "I feel that cloud_service makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_4)) +geom_bar() + labs(title = "I feel that cloud service makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   14
# 2                2 - Disagree   26
# 3                 3 - Neutral   47
# 4                   4 - Agree   89
# 5          5 - Strongly agree   66
# 6 I have not used this method   17
# plot without title
# plot without title

# %% [markdown]
# #Email

# %%
email <- as.data.frame(table(answered_seedphrase_correctly$Q17_5))
print(email)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_5))) +geom_bar() + labs(title = "I feel that email makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_5)) +geom_bar() + labs(title = "I feel that email makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   16
# 2                2 - Disagree   29
# 3                 3 - Neutral   56
# 4                   4 - Agree   69
# 5          5 - Strongly agree   67
# 6 I have not used this method   22
# plot without title
# plot without title

# %% [markdown]
# #Memorizing in the brain

# %%
memorizing <- as.data.frame(table(answered_seedphrase_correctly$Q17_6))
print(memorizing)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_6))) +geom_bar() + labs(title = "I feel that Memorizing in the brain makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_6)) +geom_bar() + labs(title = "I feel that Memorizing in the brain makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   29
# 2                2 - Disagree   40
# 3                 3 - Neutral   51
# 4                   4 - Agree   61
# 5          5 - Strongly agree   56
# 6 I have not used this method   22
# plot without title
# plot without title

# %% [markdown]
# #Safe and Secure Q18: On a scale of 1-5, choose how much you agree with the following statement: I feel that this method is safe and secure
#
# #Paper backup

# %%
paper_backup_ss <- as.data.frame(table(answered_seedphrase_correctly$Q18_1))
print(paper_backup_ss)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q18_1))) +geom_bar() + labs(title = "Paper backup - I feel that this method is safe and secure.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_1)) +geom_bar() + labs(title = "Paper backup - I feel that this method is safe and secure.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   21
# 2                2 - Disagree   26
# 3                 3 - Neutral   37
# 4                   4 - Agree   91
# 5          5 - Strongly agree   76
# 6 I have not used this method    8
# plot without title
# plot without title

# %% [markdown]
# #External Drive

# %%
external_drives <- as.data.frame(table(answered_seedphrase_correctly$Q18_2))
print(external_drives)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q18_2))) +geom_bar() + labs(title = "I feel that external_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q18_2)) +geom_bar() + labs(title = "I feel that external_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   12
# 2                2 - Disagree   26
# 3                 3 - Neutral   48
# 4                   4 - Agree   99
# 5          5 - Strongly agree   61
# 6 I have not used this method   13
# plot without title
# plot without title

# %% [markdown]
# # Internal Drive

# %%
internal_drives <- as.data.frame(table(answered_seedphrase_correctly$Q18_3))
print(internal_drives)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q18_3))) +geom_bar() + labs(title = "I feel that internal_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q18_3)) +geom_bar() + labs(title = "I feel that internal_drive makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   19
# 2                2 - Disagree   34
# 3                 3 - Neutral   59
# 4                   4 - Agree   77
# 5          5 - Strongly agree   53
# 6 I have not used this method   17
# plot without title
# plot without title

# %% [markdown]
# #Cloud Service

# %%
cloud_services <- as.data.frame(table(answered_seedphrase_correctly$Q18_4))
print(cloud_services)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q17_4))) +geom_bar() + labs(title = "I feel that cloud_service makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q17_4)) +geom_bar() + labs(title = "I feel that cloud service makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   23
# 2                2 - Disagree   33
# 3                 3 - Neutral   48
# 4                   4 - Agree   89
# 5          5 - Strongly agree   52
# 6 I have not used this method   14
# plot without title
# plot without title

# %% [markdown]
# #Email

# %%
emails <- as.data.frame(table(answered_seedphrase_correctly$Q18_5))
print(emails)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q18_5))) +geom_bar() + labs(title = "I feel that email makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q18_5)) +geom_bar() + labs(title = "I feel that email makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   30
# 2                2 - Disagree   40
# 3                 3 - Neutral   50
# 4                   4 - Agree   75
# 5          5 - Strongly agree   50
# 6 I have not used this method   14
# plot without title
# plot without title

# %% [markdown]
# #Memorizing in the brain

# %%
memorizings <- as.data.frame(table(answered_seedphrase_correctly$Q18_6))
print(memorizings)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q18_6))) +geom_bar() + labs(title = "I feel that Memorizing in the brain makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q18_6)) +geom_bar() + labs(title = "I feel that Memorizing in the brain makes it easy for me to access my seed phrase backup.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                          Var1 Freq
# 1       1 - Strongly disagree   25
# 2                2 - Disagree   31
# 3                 3 - Neutral   52
# 4                   4 - Agree   69
# 5          5 - Strongly agree   66
# 6 I have not used this method   16
# plot without title
# plot without title

# %% [markdown]
# # RQ1: Learning Strategies
# #Q19: On a scale of 1-5, choose how much you agree: I learned a lot about backing up seed phrases from (the following methods)

# %% [markdown]
# Cryptocurrency wallet apps usage

# %%
wallet_apps <- as.data.frame(table(answered_seedphrase_correctly$Q19_1))
print(wallet_apps)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q19_1))) +geom_bar() + labs(title = " I learned a lot about backing up seed phrases from Cryptocurrency wallet apps usage ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q19_1)) +geom_bar() + labs(title = "I learned a lot about backing up seed phrases from Cryptocurrency wallet apps usage", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree    5
# 2          2 - Disagree   24
# 3           3 - Neutral   59
# 4             4 - Agree  130
# 5    5 - Strongly agree   41
# plot without title
# plot without title

# %% [markdown]
# #Social media feeds

# %%
social_media <- as.data.frame(table(answered_seedphrase_correctly$Q19_2))
print(social_media)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q19_2))) +geom_bar() + labs(title = " I learned a lot about backing up seed phrases from social_mediae ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q19_2)) +geom_bar() + labs(title = "I learned a lot about backing up seed phrases from social_media", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   34
# 2          2 - Disagree   54
# 3           3 - Neutral   66
# 4             4 - Agree   72
# 5    5 - Strongly agree   33
# plot without title
# plot without title

# %% [markdown]
# #Books, news, or articles

# %%
books <- as.data.frame(table(answered_seedphrase_correctly$Q19_3))
print(books)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q19_3))) +geom_bar() + labs(title = " I learned a lot about backing up seed phrases from books ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q19_3)) +geom_bar() + labs(title = "I learned a lot about backing up seed phrases from books", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   27
# 2          2 - Disagree   25
# 3           3 - Neutral   87
# 4             4 - Agree   87
# 5    5 - Strongly agree   33
# plot without title
# plot without title

# %% [markdown]
# #People close to you

# %%
people <- as.data.frame(table(answered_seedphrase_correctly$Q19_4))
print(people)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q19_4))) +geom_bar() + labs(title = " I learned a lot about backing up seed phrases from people ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q19_4)) +geom_bar() + labs(title = "I learned a lot about backing up seed phrases from people", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   30
# 2          2 - Disagree   37
# 3           3 - Neutral   66
# 4             4 - Agree   91
# 5    5 - Strongly agree   35
# plot without title
# plot without title

# %% [markdown]
# #Online communities, chat groups and forums (e.g. Reddit)

# %%
online_community <- as.data.frame(table(answered_seedphrase_correctly$Q19_5))
print(online_community)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q19_5))) +geom_bar() + labs(title = " I learned a lot about backing up seed phrases from online_community ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q19_5)) +geom_bar() + labs(title = "I learned a lot about backing up seed phrases from online_community", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree   19
# 2          2 - Disagree   38
# 3           3 - Neutral   73
# 4             4 - Agree   89
# 5    5 - Strongly agree   40
# plot without title
# plot without title

# %% [markdown]
# #Q20-Have you ever shared your seed phrases with someone else for any of the following reasons?

# %%
shared_seed_phrase <- data.frame(table(answered_seedphrase_correctly$Q20_1),table(answered_seedphrase_correctly$Q20_2),table(answered_seedphrase_correctly$Q20_3),table(answered_seedphrase_correctly$Q20_4),table(answered_seedphrase_correctly$Q20_5))
shared_seed_phrase <- t(shared_seed_phrase)
print(shared_seed_phrase)

# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q20_", 1:5)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "X"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q20_1" = "Shared Account",
  "Q20_2" = " Backup",
  "Q20_3" = "Account Recovery",
  "Q20_4" = "None",
  "Q20_5" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "Have you ever shared your seed phrases with someone else for any of the following reasons",
       x = "Option",
       y = "Count") +
  theme_minimal()
# Out:
#        [,1]
# Var1   "For a shared account (i.e you and others invest in cryptocurrency together, you may have created a single account actively shared by several people, or you have an account that can be accessed by others, or you created a threshold signature account, etc.)"
# Freq   "58"
# Var1.1 "For backup purposes (part of your seed phrases or an entire copy of your seed phrases)"
# Freq.1 "78"
# Var1.2 "For account recovery (i.e your loved ones will be able to recover the crypto if you pass away or are severely injured.)"
# Freq.2 "61"
# Var1.3 "I haven’t shared my seed phrases with anyone."
# Freq.3 "137"
# Var1.4 "Other (please specify)"
# Freq.4 "1"
# plot without title

# %% [markdown]
# Most people do not share their seed phrases.

# %% [markdown]
# #Q21: On a scale of 1-5, choose how much you agree: I trust the individuals I've shared my seed phrases with.

# %%
trusted_individuals <- as.data.frame(table(answered_seedphrase_correctly$Q21))
print(trusted_individuals)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q21))) +geom_bar() + labs(title = "I trust the individuals I've shared my seed phrases with. ", x = "Option", y = "Frequency")

ggplot(answered_seedphrase_correctly, aes(x= Q21)) +geom_bar() + labs(title = "I trust the individuals I've shared my seed phrases with.", x = "Option", y = "Frequency") + theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                    Var1 Freq
# 1 1 - Strongly disagree    3
# 2          2 - Disagree    7
# 3           3 - Neutral   32
# 4             4 - Agree   65
# 5    5 - Strongly agree   35
# plot without title
# plot without title

# %% [markdown]
# most people seem to share their seed phrases with those they trust.

# %% [markdown]
# #Q22: In your opinion, what are the most critical factors influencing trust when it comes to sharing seed phrases with others? (Choose all that apply)

# %%
influence_trust_seed_phrase <- data.frame(table(answered_seedphrase_correctly$Q22_1),table(answered_seedphrase_correctly$Q22_2),table(answered_seedphrase_correctly$Q22_3),table(answered_seedphrase_correctly$Q22_4),table(answered_seedphrase_correctly$Q22_5),table(answered_seedphrase_correctly$Q22_6))
influence_trust_seed_phrase <- t(influence_trust_seed_phrase)
print(influence_trust_seed_phrase)

# Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q22_", 1:6)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "Reason"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q22_1" = "Personal Relationship",
  "Q22_2" = " Legal Agreement",
  "Q22_3" = "Knowledge",
  "Q22_4" = "Reputation",
  "Q22_5" = "Third-party verification",
  "Q22_6" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "Have you ever shared your seed phrases with someone else for any of the following reasons",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#        [,1]
# Var1   "Personal relationship and history with the individual"
# Freq   "133"
# Var1.1 "Legal agreements and documentation"
# Freq.1 "113"
# Var1.2 "Knowledge and understanding of seed phrase security"
# Freq.2 "124"
# Var1.3 "Reputation and credibility of the individual"
# Freq.3 "104"
# Var1.4 "Third-party verification or validation"
# Freq.4 "52"
# Var1.5 "Other (please specify)"
# Freq.5 "4"
# plot without title

# %% [markdown]
# People's personal relationships influence their trust in sharing their seedphrases.

# %% [markdown]
# #Q23: In the event of your passing, how do you envision your spouse or beneficiaries gaining access to your cryptocurrency holdings?

# %%
access <- as.data.frame(table(answered_seedphrase_correctly$Q23))
print(access)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= fct_infreq(Q23))) +geom_bar() + labs(title = "In the event of your passing, how do you envision your spouse or beneficiaries gaining access to your cryptocurrency holdings? ", x = "Option", y = "Frequency")  +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))

ggplot(answered_seedphrase_correctly, aes(x= Q23)) +geom_bar() + labs(title = "In the event of your passing, how do you envision your spouse or beneficiaries gaining access to your cryptocurrency holdings?.", x = "Option", y = "Frequency")  +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#                                                          Var1 Freq
# 1          A New Device with the Wallet Application Installed   13
# 2 Access to Registered Email or Phone Number for Verification   58
# 3          Backup of Wallet Data stored on an External Device   40
# 4               None of the Above (Please specify the reason)    9
# 5 Physical Security Token or Two-Factor Authentication Device   26
# 6                                                 Private Key   40
# 7                                        Recovery Seed Phrase   93
# plot without title
# plot without title

# %% [markdown]
# People share their recovery seed phrases to their partners in the case of their demise, which relates to personal relationships being the main motivation for trust in sharing seed phrases.

# %% [markdown]
# #Q38:Have you tried sharing wallets / accounts with others (i.e., created a single wallet actively shared by several people, or a wallet that others can access, or a threshold signature account, etc.)?

# %%
sharing <- as.data.frame(table(answered_seedphrase_correctly$Q38))
print(sharing)

#print barplot
ggplot(answered_seedphrase_correctly, aes(x= Q38)) +geom_bar() + labs(title = ":Have you tried sharing wallets / accounts with others", x = "Option", y = "Frequency")
# Out:
#   Var1 Freq
# 1   No  221
# 2  Yes   58
# plot without title

# %% [markdown]
# #Q39: Think about the last time you shared a wallet / account with someone else. Why did you share this wallet? Choose all that apply.

# %%
reas_sharing <- data.frame(table(answered_seedphrase_correctly$Q39_1),table(answered_seedphrase_correctly$Q39_2),table(answered_seedphrase_correctly$Q39_3),table(answered_seedphrase_correctly$Q39_4))
# print(table(answered_seedphrase_correctly$Q39_4))
# print(table(answered_seedphrase_correctly$Q39_5))
reas_sharing <- t(reas_sharing)
print(reas_sharing)
#Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q39_", 1:4)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "Reason"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q39_1" = "financial goals",
  "Q39_2" = "emergencies",
  "Q39_3" = "trust_in_rel",
  "Q39_4" = "Simplifying mgt",
  "Q39_5" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "How do you currently back up your cryptocurrency wallet's seed phrases?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#        [,1]
# Var1   "Facilitating joint financial goals or investments"
# Freq   "20"
# Var1.1 "Ensuring access to assets in case of emergencies or incapacitation"
# Freq.1 "33"
# Var1.2 "Enhanced trust and transparency in the relationship"
# Freq.2 "27"
# Var1.3 "Simplifying the management of shared crypto assets"
# Freq.3 "12"
# plot without title

# %% [markdown]
# Most people do not share their wallet with others, but when they do, its mainly for emergencies. Which shows why People share their recovery seed phrases with their partners in the case of their demise, which relates to personal relationships being the main motivation for trust in sharing seed phrases.

# %% [markdown]
# #Q40: Which of the following would you prefer to enhance the security of shared accounts? Choose all that apply.

# %%
enhance_security <- data.frame(table(answered_seedphrase_correctly$Q40_1),table(answered_seedphrase_correctly$Q40_2),table(answered_seedphrase_correctly$Q40_3),table(answered_seedphrase_correctly$Q40_4),table(answered_seedphrase_correctly$Q40_5))

enhance_security <- t(enhance_security)
print(enhance_security)
#Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_seedphrase_correctly[, paste0("Q40_", 1:5)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "option"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q40_1" = "passwords",
  "Q40_2" = "splitting",
  "Q40_3" = "multiple wallets",
  "Q40_4" = "investing less money",
  "Q40_5" = "rules for trading"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "How do you currently back up your cryptocurrency wallet's seed phrases?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#        [,1]
# Var1   "Setting passwords for the seed phrases"
# Freq   "19"
# Var1.1 "Splitting up seed phrases into multiple phrases"
# Freq.1 "28"
# Var1.2 "Keeping multiple wallets"
# Freq.2 "24"
# Var1.3 "Investing less money"
# Freq.3 "12"
# Var1.4 "Setting up the rules for trading, conflicts, and quitting"
# Freq.4 "10"
# plot without title

# %% [markdown]
# Most people would like to split up seed phrases into multiple phrases if they have a shared account.

# %% [markdown]
# #Those that did not answer seed phrase correctly

# %%
answered_incorrectly <-data_finale |>
filter(Q8 != "Seed Phrase")
head(answered_incorrectly)
# Out:
#   Q1  Q2
# 1 Yes More than 5 years
# 2 Yes 1 to 2 years
# 3 Yes 2 to 5 years
# 4 Yes Less than 6 months
# 5 Yes 1 to 2 years
# 6 Yes 2 to 5 years
#   Q3_1
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 Research (i.e to research how it works, scholarly purposes, etc)
# 6 Research (i.e to research how it works, scholarly purposes, etc)
#   Q3_2                                 Q3_3
# 1 NA                                   NA
# 2 Financial Planning (i.e. investment) NA
# 3 Financial Planning (i.e. investment) NA
# 4 NA                                   NA
# 5 NA                                   NA
# 6 NA                                   NA
#   Q3_4                                                          Q3_5
# 1 NA                                                            Entertainment
# 2 NA                                                            NA
# 3 NA                                                            NA
# ...

# %% [markdown]
# #Q2: How long have you been using crypto?

# %%
yrs_inc <- answered_incorrectly$Q2
freq_df <- as.data.frame(table(yrs_inc))
print(freq_df)
# Out:
#              yrs_inc Freq
# 1       1 to 2 years   97
# 2       2 to 5 years   69
# 3 6 months to 1 year   87
# 4 Less than 6 months   86
# 5  More than 5 years   25

# %%
ggplot(answered_incorrectly, aes(x= fct_infreq(Q2))) +geom_bar() + labs(title = "Q2: How long have you been using crypto?", x = "Years of Experience", y = "Frequency")
# Out:
# plot without title

# %% [markdown]
# #Q3 - What motivated you to start trading crypto?

# %%
motivation_cori <- data.frame(answered_incorrectly$Q3_1,answered_incorrectly$Q3_2,answered_incorrectly$Q3_3,answered_incorrectly$Q3_4,answered_incorrectly$Q3_5)
head(motivation_cori)
# Out:
#   answered_incorrectly.Q3_1
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 Research (i.e to research how it works, scholarly purposes, etc)
# 6 Research (i.e to research how it works, scholarly purposes, etc)
#   answered_incorrectly.Q3_2            answered_incorrectly.Q3_3
# 1 NA                                   NA
# 2 Financial Planning (i.e. investment) NA
# 3 Financial Planning (i.e. investment) NA
# 4 NA                                   NA
# 5 NA                                   NA
# 6 NA                                   NA
#   answered_incorrectly.Q3_4
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 Monetary transactions (i.e, transfer funds, pay for products)
#   answered_incorrectly.Q3_5
# 1 Entertainment
# 2 NA
# 3 NA
# 4 Entertainment
# 5 NA
# 6 Entertainment

# %%
research <- table(answered_incorrectly$Q3_1)
print(research)
fin_pl <- table(answered_incorrectly$Q3_2)
print(fin_pl)
work <- table(answered_incorrectly$Q3_3)
print(work)
mon_tr <- table(answered_incorrectly$Q3_4)
print(mon_tr)
ent <- table(answered_incorrectly$Q3_5)
print(ent)
# Out:
# Research (i.e to research how it works, scholarly purposes, etc)
#                                                              132
#
# Financial Planning (i.e. investment)
#                                  167
#
# Work (i.e for a business transaction)
#                                    54
#
# Monetary transactions (i.e, transfer funds, pay for products)
#                                                            96
#
# Entertainment
#           102

# %%
responses <- answered_incorrectly[, paste0("Q3_", 1:5)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "option"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q3_1" = "Research",
  "Q3_2" = "Financial Planning",
  "Q3_3" = "Work",
  "Q3_4" = "Monetary transactions",
  "Q3_5" = "Entertainment"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "What motivated you to start trading crypto?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
responses <- answered_incorrectly[, paste0("Q3_", 1:5)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "option"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q3_1" = "Research",
  "Q3_2" = "Financial Planning",
  "Q3_3" = "Work",
  "Q3_4" = "Monetary transactions",
  "Q3_5" = "Entertainment"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "What motivated you to start trading crypto?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# Conforming to motivations from overall data on motivations, financial planning and research remains the biggest motivation and work is the lowest.

# %% [markdown]
# #Q4: What kind of wallet do you mostly use?

# %%
kind_of_wallet_tablet_cor <- data.frame(table(answered_incorrectly$Q4_1),table(answered_incorrectly$Q4_2),table(answered_incorrectly$Q4_3),table(answered_incorrectly$Q4_4),table(answered_incorrectly$Q4_5),table(answered_incorrectly$Q4_6),table(answered_incorrectly$Q4_7))
kind_of_wallet_tablet_cor <- t(kind_of_wallet_tablet_cor)
print(kind_of_wallet_tablet_cor)
# Out:
#        [,1]
# Var1   "Hosted Web Wallet (e.g., wallets provided by cryptocurrency exchanges like Coinbase, Gemini, and Binance)"
# Freq   "173"
# Var1.1 "Non-hosted Web Wallet (e.g., MetaMask, Electrum, MyEtherWallet)"
# Freq.1 "46"
# Var1.2 "Desktop Wallet (e.g., Bitcoin Core, Exodus, Armory, Wasabi Wallet)"
# Freq.2 "103"
# Var1.3 "Mobile Wallet (e.g., BRD, Mycelium, Trust Wallet)"
# Freq.3 "134"
# Var1.4 "Hardware Wallet (e.g., Ledger Nano S, Trezor, BitBox)"
# Freq.4 "29"
# Var1.5 "Paper Wallet (Offline paper storage)"
# Freq.5 "22"
# Var1.6 "Other (please specify)"
# Freq.6 "5"

# %% [markdown]
# #Q5:What is your most used crypto trading platform? - Selected Choice

# %%
most_used_crypto_platform_cor <- as.data.frame(table(answered_incorrectly$Q5))
print(most_used_crypto_platform_cor)

#print barplot
ggplot(answered_incorrectly, aes(x= fct_infreq(Q5))) +geom_bar() + labs(title = "Q5:What is your most used crypto trading platform? ", x = "Platform", y = "Frequency")
# Out:
#                     Var1 Freq
# 1                Binance   57
# 2        Coinbase wallet  195
# 3           Coinbase web   65
# 4               Metamask   25
# 5 Other (please specify)   22
# plot without title

# %% [markdown]
# #Q6: How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)

# %%
num_of_active_trading_wallet_cor <- answered_incorrectly$Q6
print(as.data.frame(table(num_of_active_trading_wallet)))
# print(num_of_active_trading_wallet)

#print barplot
ggplot(answered_incorrectly, aes(x= fct_infreq(Q6))) +geom_bar() + labs(title = " How many wallets do you actively trade with? (i.e., with which you buy/sell/send/receive crypto)", x = "Number of Active trading wallet", y = "Frequency")
# Out:
#   num_of_active_trading_wallet Freq
# 1                            0   26
# 2                          1-5  557
# 3                         5-10   45
# 4                 More than 10   15
# plot without title

# %% [markdown]
# #Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)

# %%
num_of_active_transactions_in_pastmth <- as.data.frame(table(answered_incorrectly$Q7))
print(num_of_active_transactions_in_pastmth)

#print barplot
ggplot(answered_incorrectly, aes(x= fct_infreq(Q7))) +geom_bar() + labs(title = " Q7:How many transactions have you done in the past month? (i.e., Transaction means you buy/sell/send/receive crypto)", x = "Number of transactions", y = "Frequency")
# Out:
#           Var1 Freq
# 1            0   60
# 2          1-5  215
# 3         5-10   59
# 4 More than 10   30
# plot without title

# %% [markdown]
# #Q26: For the following questions, please focus your responses on a single cryptocurrency wallet (e.g. MetaMask, Electrum, Trust Wallet, etc) for this survey. Choose either your most important wallet or the one you use most frequently. Please specify the wallet you choose below.

# %%
# Select the columns
responses <- answered_incorrectly[, paste0("Q26_", 1:9)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "Selected Choice"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q26_1" = "Username and Password",
  "Q26_2" = "Private Key",
  "Q26_3" = "Recovery Seed Phrase",
  "Q26_4" = "Wallet Password",
  "Q26_5" = "Two-Factor Authentication Codes",
  "Q26_6" = "Email Address associated with Wallet",
  "Q26_7" = "Backup Files from Wallet Application",
  "Q26_8" = "Pin",
  "Q26_9" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "Which of the following methods do you use to secure your crypto wallet?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# #Q38: Have you tried sharing wallets / accounts with others (i.e., created a single wallet actively shared by several people, or a wallet that others can access, or a threshold signature account, etc.)?

# %%
share_sp<- as.data.frame(table(answered_incorrectly$Q38))
print(share_sp)

#print barplot
ggplot(answered_incorrectly, aes(x= Q38)) +geom_bar() + labs(title = "Have you tried sharing wallets / accounts with others", x = "Option", y = "Frequency")
# Out:
#   Var1 Freq
# 1   No  268
# 2  Yes   96
# plot without title

# %% [markdown]
# #Q39: Think about the last time you shared a wallet / account with someone else. Why did you share this wallet?

# %%
reas_sharing <- data.frame(table(answered_incorrectly$Q39_1),table(answered_incorrectly$Q39_2),table(answered_incorrectly$Q39_3),table(answered_incorrectly$Q39_4))
reas_sharing <- t(reas_sharing)
print(reas_sharing)
#Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_incorrectly[, paste0("Q39_", 1:4)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "X"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q39_1" = "Facilitating joint financial goals",
  "Q39_2" = "Ensuring access to assets in case of emergencies",
  "Q39_3" = "Enhanced trust and transparency in the relationship",
  "Q39_4" = "Simplifying the management of shared crypto assets",
  "Q39_5" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "Think about the last time you shared a wallet /
  account with someone else.
   Why did you share this wallet?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
#        [,1]
# Var1   "Facilitating joint financial goals or investments"
# Freq   "30"
# Var1.1 "Ensuring access to assets in case of emergencies or incapacitation"
# Freq.1 "58"
# Var1.2 "Enhanced trust and transparency in the relationship"
# Freq.2 "50"
# Var1.3 "Simplifying the management of shared crypto assets"
# Freq.3 "26"
# plot without title

# %% [markdown]
# #Q40: Which of the following would you prefer to enhance the security of shared accounts?

# %%
enhance_security <- data.frame(table(answered_incorrectly$Q40_1),table(answered_incorrectly$Q40_2),table(answered_incorrectly$Q40_3),table(answered_incorrectly$Q40_4),table(answered_incorrectly$Q40_5))

enhance_security <- t(enhance_security)
print(enhance_security)
#Select the columns corresponding to Q10_1 to Q10_10
responses <- answered_incorrectly[, paste0("Q40_", 1:6)]

# Replace non-empty cells with 1 and empty cells with 0
responses[responses != ""] <- "option"
responses[responses == ""] <- NA

# Convert the data to long format
responses_long <- gather(responses, key = "Question", value = "Chosen")

# mapping column names to options
option_names <- c(
  "Q40_1" = "Setting passwords for the seed phrases",
  "Q40_2" = "Splitting up seed phrases into multiple phrases",
  "Q40_3" = "Keeping multiple wallets",
  "Q40_4" = "investing less money",
  "Q40_5" = "Setting up the rules for trading, conflicts, and quitting",
  "Q40_6" = "Other"
)
responses_long$Question <- option_names[responses_long$Question]

# Plot the stacked bar plot
ggplot(responses_long, aes(x = Question, fill = Chosen)) +
  geom_bar() +
  labs(title = "How do you currently back up your cryptocurrency wallet's seed phrases?",
       x = "Option",
       y = "Count") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
#        [,1]
# Var1   "Setting passwords for the seed phrases"
# Freq   "44"
# Var1.1 "Splitting up seed phrases into multiple phrases"
# Freq.1 "36"
# Var1.2 "Keeping multiple wallets"
# Freq.2 "44"
# Var1.3 "Investing less money"
# Freq.3 "30"
# Var1.4 "Setting up the rules for trading, conflicts, and quitting"
# Freq.4 "18"
# plot without title

# %% [markdown]
# Most people either keep multiple wallets or set up passwords for their seedphrases

# %% [markdown]
# **Hypothesis 1**
